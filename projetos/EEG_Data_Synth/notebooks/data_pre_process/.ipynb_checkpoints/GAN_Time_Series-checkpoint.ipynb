# %%
import torch
from torch import nn
from tqdm.auto import tqdm
from torchvision import transforms, utils
from torchvision.datasets import MNIST
from torchvision.utils import make_grid
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
torch.manual_seed(0) # Set for our testing purposes, please do not change!

from braindecode.datasets import MOABBDataset
from braindecode.preprocessing import (
    exponential_moving_standardize, preprocess, Preprocessor)
from braindecode.preprocessing import \
    create_windows_from_events, create_fixed_length_windows
import pandas as pd
import numpy as np


def show_tensor_images(image_tensor, num_images=25, size=(1, 28, 28), nrow=5, show=True):
    '''
    Function for visualizing images: Given a tensor of images, number of images, and
    size per image, plots and prints the images in an uniform grid.
    '''
    image_tensor = (image_tensor + 1) / 2
    image_unflat = image_tensor.detach().cpu()
    image_grid = make_grid(image_unflat[:num_images], nrow=nrow)
    plt.imshow(image_grid.permute(1, 2, 0).squeeze())
    if show:
        plt.show()

# %% [markdown]
# # Creating function to get EEG Data

# %% [markdown]
# ## Preprocess Function

# %%
def preprocessor(
    dataset,
    low_cut_hz = 4.,   # low cut frequency for filtering
    high_cut_hz = 38., # high cut frequency for filtering
    newfreq = 100, # Paramater for resampling
    factor = 1e6, # Parameter for scaling
    ):

    preprocessors = [
        Preprocessor('pick_types', eeg=True, meg=False, stim=False),  # Keep EEG sensors
        Preprocessor(lambda data: np.multiply(data, factor)),  # Convert from V to uV
        Preprocessor("resample", sfreq=newfreq), # Resampling
        Preprocessor('filter', l_freq=low_cut_hz, h_freq=high_cut_hz),  # Bandpass filter
        Preprocessor("set_eeg_reference", ref_channels="average", ch_type="eeg") # Common Average Reference
    ]
    
    # Transform the data
    return preprocess(dataset, preprocessors, n_jobs = -1)

# %% [markdown]
# ## Get Windows from Dataset function

# %%
def get_windows(
        dataset, 
        trial_start_offset_samples=0,
        trial_stop_offset_samples=100,
        window_size_samples=400,
        window_stride_samples=100,
        preload=True,
        # mapping = {'left_hand': 0, 'right_hand': 1},
        picks = ['C3', 'Cz', 'C4']
        ):
    
    windows_dataset = create_windows_from_events(
        dataset,
        trial_start_offset_samples = trial_start_offset_samples,
        trial_stop_offset_samples  = trial_stop_offset_samples,
        window_size_samples        = window_size_samples,
        window_stride_samples      = window_stride_samples,
        preload                    = True,
        # mapping = {'left_hand': 0, 'right_hand': 1},
        picks                      = picks
        )
    
    return windows_dataset


def get_tensors_from_windows(windows_dataset):
    windows_list = []
    labels_list = []
    n_runs = len(windows_dataset.datasets)
    for i in range(n_runs):
        windows_list.append(windows_dataset.datasets[i].windows.get_data())
        labels_list.append(windows_dataset.datasets[i].y)
        
    stacked_tensor = np.concatenate(windows_list, axis=0)
    stacked_labels = np.concatenate(labels_list, axis=0)
    
    del windows_list,labels_list
    
    return stacked_tensor, stacked_labels

# %% [markdown]
# # Creating EEG Dataset Class

# %%
class EEG(Dataset):

    def __init__(self, subject_id = 3, dataset_name="BNCI2014_001", transform = None):
        
        self.raw_dataset     = MOABBDataset(dataset_name = dataset_name, subject_ids=[subject_id])
        self.prepro_dataset  = preprocessor(self.raw_dataset)
        self.windows_dataset = get_windows(self.prepro_dataset)
        self.data            = get_tensors_from_windows(self.windows_dataset)
        self.transform = transform
        
    def __len__(self):
        return self.data[0].shape[0]

        
    def __getitem__(self,idx):
        
        sample = {'signal': torch.from_numpy(self.data[0])[idx], 'label': torch.from_numpy(self.data[1])[idx]}
        
        if self.transform:
            sample = self.transform(sample)
            
        return sample

# %%
my_eeg_data = EEG()
# Out:
# /usr/local/lib/python3.11/dist-packages/braindecode/preprocessing/preprocess.py:55: UserWarning: Preprocessing choices with lambda functions cannot be saved.
#   warn('Preprocessing choices with lambda functions cannot be saved.')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
#
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 165 samples (1.650 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']

# %%
# data loader
dataloader = DataLoader(my_eeg_data, batch_size=4,
                        shuffle=True, num_workers=0)

# %%
train_features, train_labels = next(iter(dataloader))

# %%
type(train_features)
# Out:
# str

# %%
for i_batch, sample_batched in enumerate(dataloader):
    print(i_batch, sample_batched['signal'].size(),
      sample_batched['label'].size())
# Out:
# 0 torch.Size([4, 3, 400]) torch.Size([4])
# 1 torch.Size([4, 3, 400]) torch.Size([4])
# 2 torch.Size([4, 3, 400]) torch.Size([4])
# 3 torch.Size([4, 3, 400]) torch.Size([4])
# 4 torch.Size([4, 3, 400]) torch.Size([4])
# 5 torch.Size([4, 3, 400]) torch.Size([4])
# 6 torch.Size([4, 3, 400]) torch.Size([4])
# 7 torch.Size([4, 3, 400]) torch.Size([4])
# 8 torch.Size([4, 3, 400]) torch.Size([4])
# 9 torch.Size([4, 3, 400]) torch.Size([4])
# 10 torch.Size([4, 3, 400]) torch.Size([4])
# 11 torch.Size([4, 3, 400]) torch.Size([4])
# 12 torch.Size([4, 3, 400]) torch.Size([4])
# 13 torch.Size([4, 3, 400]) torch.Size([4])
# 14 torch.Size([4, 3, 400]) torch.Size([4])
# 15 torch.Size([4, 3, 400]) torch.Size([4])
# 16 torch.Size([4, 3, 400]) torch.Size([4])
# 17 torch.Size([4, 3, 400]) torch.Size([4])
# 18 torch.Size([4, 3, 400]) torch.Size([4])
# 19 torch.Size([4, 3, 400]) torch.Size([4])
# 20 torch.Size([4, 3, 400]) torch.Size([4])
# 21 torch.Size([4, 3, 400]) torch.Size([4])
# 22 torch.Size([4, 3, 400]) torch.Size([4])
# 23 torch.Size([4, 3, 400]) torch.Size([4])
# 24 torch.Size([4, 3, 400]) torch.Size([4])
# 25 torch.Size([4, 3, 400]) torch.Size([4])
# 26 torch.Size([4, 3, 400]) torch.Size([4])
# 27 torch.Size([4, 3, 400]) torch.Size([4])
# 28 torch.Size([4, 3, 400]) torch.Size([4])
# 29 torch.Size([4, 3, 400]) torch.Size([4])
# 30 torch.Size([4, 3, 400]) torch.Size([4])
# 31 torch.Size([4, 3, 400]) torch.Size([4])
# 32 torch.Size([4, 3, 400]) torch.Size([4])
# 33 torch.Size([4, 3, 400]) torch.Size([4])
# 34 torch.Size([4, 3, 400]) torch.Size([4])
# 35 torch.Size([4, 3, 400]) torch.Size([4])
# 36 torch.Size([4, 3, 400]) torch.Size([4])
# 37 torch.Size([4, 3, 400]) torch.Size([4])
# 38 torch.Size([4, 3, 400]) torch.Size([4])
# 39 torch.Size([4, 3, 400]) torch.Size([4])
# 40 torch.Size([4, 3, 400]) torch.Size([4])
# 41 torch.Size([4, 3, 400]) torch.Size([4])
# 42 torch.Size([4, 3, 400]) torch.Size([4])
# 43 torch.Size([4, 3, 400]) torch.Size([4])
# 44 torch.Size([4, 3, 400]) torch.Size([4])
# 45 torch.Size([4, 3, 400]) torch.Size([4])
# 46 torch.Size([4, 3, 400]) torch.Size([4])
# 47 torch.Size([4, 3, 400]) torch.Size([4])
# 48 torch.Size([4, 3, 400]) torch.Size([4])
# 49 torch.Size([4, 3, 400]) torch.Size([4])
# 50 torch.Size([4, 3, 400]) torch.Size([4])
# 51 torch.Size([4, 3, 400]) torch.Size([4])
# 52 torch.Size([4, 3, 400]) torch.Size([4])
# 53 torch.Size([4, 3, 400]) torch.Size([4])
# 54 torch.Size([4, 3, 400]) torch.Size([4])
# 55 torch.Size([4, 3, 400]) torch.Size([4])
# 56 torch.Size([4, 3, 400]) torch.Size([4])
# 57 torch.Size([4, 3, 400]) torch.Size([4])
# 58 torch.Size([4, 3, 400]) torch.Size([4])
# 59 torch.Size([4, 3, 400]) torch.Size([4])
# 60 torch.Size([4, 3, 400]) torch.Size([4])
# 61 torch.Size([4, 3, 400]) torch.Size([4])
# 62 torch.Size([4, 3, 400]) torch.Size([4])
# 63 torch.Size([4, 3, 400]) torch.Size([4])
# 64 torch.Size([4, 3, 400]) torch.Size([4])
# 65 torch.Size([4, 3, 400]) torch.Size([4])
# 66 torch.Size([4, 3, 400]) torch.Size([4])
# 67 torch.Size([4, 3, 400]) torch.Size([4])
# 68 torch.Size([4, 3, 400]) torch.Size([4])
# 69 torch.Size([4, 3, 400]) torch.Size([4])
# 70 torch.Size([4, 3, 400]) torch.Size([4])
# 71 torch.Size([4, 3, 400]) torch.Size([4])
# 72 torch.Size([4, 3, 400]) torch.Size([4])
# 73 torch.Size([4, 3, 400]) torch.Size([4])
# 74 torch.Size([4, 3, 400]) torch.Size([4])
# 75 torch.Size([4, 3, 400]) torch.Size([4])
# 76 torch.Size([4, 3, 400]) torch.Size([4])
# 77 torch.Size([4, 3, 400]) torch.Size([4])
# 78 torch.Size([4, 3, 400]) torch.Size([4])
# 79 torch.Size([4, 3, 400]) torch.Size([4])
# 80 torch.Size([4, 3, 400]) torch.Size([4])
# 81 torch.Size([4, 3, 400]) torch.Size([4])
# 82 torch.Size([4, 3, 400]) torch.Size([4])
# 83 torch.Size([4, 3, 400]) torch.Size([4])
# 84 torch.Size([4, 3, 400]) torch.Size([4])
# 85 torch.Size([4, 3, 400]) torch.Size([4])
# 86 torch.Size([4, 3, 400]) torch.Size([4])
# 87 torch.Size([4, 3, 400]) torch.Size([4])
# 88 torch.Size([4, 3, 400]) torch.Size([4])
# 89 torch.Size([4, 3, 400]) torch.Size([4])
# 90 torch.Size([4, 3, 400]) torch.Size([4])
# 91 torch.Size([4, 3, 400]) torch.Size([4])
# 92 torch.Size([4, 3, 400]) torch.Size([4])
# 93 torch.Size([4, 3, 400]) torch.Size([4])
# 94 torch.Size([4, 3, 400]) torch.Size([4])
# 95 torch.Size([4, 3, 400]) torch.Size([4])
# 96 torch.Size([4, 3, 400]) torch.Size([4])
# 97 torch.Size([4, 3, 400]) torch.Size([4])
# 98 torch.Size([4, 3, 400]) torch.Size([4])
# 99 torch.Size([4, 3, 400]) torch.Size([4])
# 100 torch.Size([4, 3, 400]) torch.Size([4])
# 101 torch.Size([4, 3, 400]) torch.Size([4])
# 102 torch.Size([4, 3, 400]) torch.Size([4])
# 103 torch.Size([4, 3, 400]) torch.Size([4])
# 104 torch.Size([4, 3, 400]) torch.Size([4])
# 105 torch.Size([4, 3, 400]) torch.Size([4])
# 106 torch.Size([4, 3, 400]) torch.Size([4])
# 107 torch.Size([4, 3, 400]) torch.Size([4])
# 108 torch.Size([4, 3, 400]) torch.Size([4])
# 109 torch.Size([4, 3, 400]) torch.Size([4])
# 110 torch.Size([4, 3, 400]) torch.Size([4])
# 111 torch.Size([4, 3, 400]) torch.Size([4])
# 112 torch.Size([4, 3, 400]) torch.Size([4])
# 113 torch.Size([4, 3, 400]) torch.Size([4])
# 114 torch.Size([4, 3, 400]) torch.Size([4])
# 115 torch.Size([4, 3, 400]) torch.Size([4])
# 116 torch.Size([4, 3, 400]) torch.Size([4])
# 117 torch.Size([4, 3, 400]) torch.Size([4])
# 118 torch.Size([4, 3, 400]) torch.Size([4])
# 119 torch.Size([4, 3, 400]) torch.Size([4])
# 120 torch.Size([4, 3, 400]) torch.Size([4])
# 121 torch.Size([4, 3, 400]) torch.Size([4])
# 122 torch.Size([4, 3, 400]) torch.Size([4])
# 123 torch.Size([4, 3, 400]) torch.Size([4])
# 124 torch.Size([4, 3, 400]) torch.Size([4])
# 125 torch.Size([4, 3, 400]) torch.Size([4])
# 126 torch.Size([4, 3, 400]) torch.Size([4])
# 127 torch.Size([4, 3, 400]) torch.Size([4])
# 128 torch.Size([4, 3, 400]) torch.Size([4])
# 129 torch.Size([4, 3, 400]) torch.Size([4])
# 130 torch.Size([4, 3, 400]) torch.Size([4])
# 131 torch.Size([4, 3, 400]) torch.Size([4])
# 132 torch.Size([4, 3, 400]) torch.Size([4])
# 133 torch.Size([4, 3, 400]) torch.Size([4])
# 134 torch.Size([4, 3, 400]) torch.Size([4])
# 135 torch.Size([4, 3, 400]) torch.Size([4])
# 136 torch.Size([4, 3, 400]) torch.Size([4])
# 137 torch.Size([4, 3, 400]) torch.Size([4])
# 138 torch.Size([4, 3, 400]) torch.Size([4])
# 139 torch.Size([4, 3, 400]) torch.Size([4])
# 140 torch.Size([4, 3, 400]) torch.Size([4])
# 141 torch.Size([4, 3, 400]) torch.Size([4])
# 142 torch.Size([4, 3, 400]) torch.Size([4])
# 143 torch.Size([4, 3, 400]) torch.Size([4])
# 144 torch.Size([4, 3, 400]) torch.Size([4])
# 145 torch.Size([4, 3, 400]) torch.Size([4])
# 146 torch.Size([4, 3, 400]) torch.Size([4])
# 147 torch.Size([4, 3, 400]) torch.Size([4])
# 148 torch.Size([4, 3, 400]) torch.Size([4])
# 149 torch.Size([4, 3, 400]) torch.Size([4])
# 150 torch.Size([4, 3, 400]) torch.Size([4])
# 151 torch.Size([4, 3, 400]) torch.Size([4])
# 152 torch.Size([4, 3, 400]) torch.Size([4])
# 153 torch.Size([4, 3, 400]) torch.Size([4])
# 154 torch.Size([4, 3, 400]) torch.Size([4])
# 155 torch.Size([4, 3, 400]) torch.Size([4])
# 156 torch.Size([4, 3, 400]) torch.Size([4])
# 157 torch.Size([4, 3, 400]) torch.Size([4])
# 158 torch.Size([4, 3, 400]) torch.Size([4])
# 159 torch.Size([4, 3, 400]) torch.Size([4])
# 160 torch.Size([4, 3, 400]) torch.Size([4])
# 161 torch.Size([4, 3, 400]) torch.Size([4])
# 162 torch.Size([4, 3, 400]) torch.Size([4])
# 163 torch.Size([4, 3, 400]) torch.Size([4])
# 164 torch.Size([4, 3, 400]) torch.Size([4])
# 165 torch.Size([4, 3, 400]) torch.Size([4])
# 166 torch.Size([4, 3, 400]) torch.Size([4])
# 167 torch.Size([4, 3, 400]) torch.Size([4])
# 168 torch.Size([4, 3, 400]) torch.Size([4])
# 169 torch.Size([4, 3, 400]) torch.Size([4])
# 170 torch.Size([4, 3, 400]) torch.Size([4])
# 171 torch.Size([4, 3, 400]) torch.Size([4])
# 172 torch.Size([4, 3, 400]) torch.Size([4])
# 173 torch.Size([4, 3, 400]) torch.Size([4])
# 174 torch.Size([4, 3, 400]) torch.Size([4])
# 175 torch.Size([4, 3, 400]) torch.Size([4])
# 176 torch.Size([4, 3, 400]) torch.Size([4])
# 177 torch.Size([4, 3, 400]) torch.Size([4])
# 178 torch.Size([4, 3, 400]) torch.Size([4])
# 179 torch.Size([4, 3, 400]) torch.Size([4])
# 180 torch.Size([4, 3, 400]) torch.Size([4])
# 181 torch.Size([4, 3, 400]) torch.Size([4])
# 182 torch.Size([4, 3, 400]) torch.Size([4])
# 183 torch.Size([4, 3, 400]) torch.Size([4])
# 184 torch.Size([4, 3, 400]) torch.Size([4])
# 185 torch.Size([4, 3, 400]) torch.Size([4])
# 186 torch.Size([4, 3, 400]) torch.Size([4])
# 187 torch.Size([4, 3, 400]) torch.Size([4])
# 188 torch.Size([4, 3, 400]) torch.Size([4])
# 189 torch.Size([4, 3, 400]) torch.Size([4])
# 190 torch.Size([4, 3, 400]) torch.Size([4])
# 191 torch.Size([4, 3, 400]) torch.Size([4])
# 192 torch.Size([4, 3, 400]) torch.Size([4])
# 193 torch.Size([4, 3, 400]) torch.Size([4])
# 194 torch.Size([4, 3, 400]) torch.Size([4])
# 195 torch.Size([4, 3, 400]) torch.Size([4])
# 196 torch.Size([4, 3, 400]) torch.Size([4])
# 197 torch.Size([4, 3, 400]) torch.Size([4])
# 198 torch.Size([4, 3, 400]) torch.Size([4])
# 199 torch.Size([4, 3, 400]) torch.Size([4])
# 200 torch.Size([4, 3, 400]) torch.Size([4])
# 201 torch.Size([4, 3, 400]) torch.Size([4])
# 202 torch.Size([4, 3, 400]) torch.Size([4])
# 203 torch.Size([4, 3, 400]) torch.Size([4])
# 204 torch.Size([4, 3, 400]) torch.Size([4])
# 205 torch.Size([4, 3, 400]) torch.Size([4])
# 206 torch.Size([4, 3, 400]) torch.Size([4])
# 207 torch.Size([4, 3, 400]) torch.Size([4])
# 208 torch.Size([4, 3, 400]) torch.Size([4])
# 209 torch.Size([4, 3, 400]) torch.Size([4])
# 210 torch.Size([4, 3, 400]) torch.Size([4])
# 211 torch.Size([4, 3, 400]) torch.Size([4])
# 212 torch.Size([4, 3, 400]) torch.Size([4])
# 213 torch.Size([4, 3, 400]) torch.Size([4])
# 214 torch.Size([4, 3, 400]) torch.Size([4])
# 215 torch.Size([4, 3, 400]) torch.Size([4])
# 216 torch.Size([4, 3, 400]) torch.Size([4])
# 217 torch.Size([4, 3, 400]) torch.Size([4])
# 218 torch.Size([4, 3, 400]) torch.Size([4])
# 219 torch.Size([4, 3, 400]) torch.Size([4])
# 220 torch.Size([4, 3, 400]) torch.Size([4])
# 221 torch.Size([4, 3, 400]) torch.Size([4])
# 222 torch.Size([4, 3, 400]) torch.Size([4])
# 223 torch.Size([4, 3, 400]) torch.Size([4])
# 224 torch.Size([4, 3, 400]) torch.Size([4])
# 225 torch.Size([4, 3, 400]) torch.Size([4])
# 226 torch.Size([4, 3, 400]) torch.Size([4])
# 227 torch.Size([4, 3, 400]) torch.Size([4])
# 228 torch.Size([4, 3, 400]) torch.Size([4])
# 229 torch.Size([4, 3, 400]) torch.Size([4])
# 230 torch.Size([4, 3, 400]) torch.Size([4])
# 231 torch.Size([4, 3, 400]) torch.Size([4])
# 232 torch.Size([4, 3, 400]) torch.Size([4])
# 233 torch.Size([4, 3, 400]) torch.Size([4])
# 234 torch.Size([4, 3, 400]) torch.Size([4])
# 235 torch.Size([4, 3, 400]) torch.Size([4])
# 236 torch.Size([4, 3, 400]) torch.Size([4])
# 237 torch.Size([4, 3, 400]) torch.Size([4])
# 238 torch.Size([4, 3, 400]) torch.Size([4])
# 239 torch.Size([4, 3, 400]) torch.Size([4])
# 240 torch.Size([4, 3, 400]) torch.Size([4])
# 241 torch.Size([4, 3, 400]) torch.Size([4])
# 242 torch.Size([4, 3, 400]) torch.Size([4])
# 243 torch.Size([4, 3, 400]) torch.Size([4])
# 244 torch.Size([4, 3, 400]) torch.Size([4])
# 245 torch.Size([4, 3, 400]) torch.Size([4])
# 246 torch.Size([4, 3, 400]) torch.Size([4])
# 247 torch.Size([4, 3, 400]) torch.Size([4])
# 248 torch.Size([4, 3, 400]) torch.Size([4])
# 249 torch.Size([4, 3, 400]) torch.Size([4])
# 250 torch.Size([4, 3, 400]) torch.Size([4])
# 251 torch.Size([4, 3, 400]) torch.Size([4])
# 252 torch.Size([4, 3, 400]) torch.Size([4])
# 253 torch.Size([4, 3, 400]) torch.Size([4])
# 254 torch.Size([4, 3, 400]) torch.Size([4])
# 255 torch.Size([4, 3, 400]) torch.Size([4])
# 256 torch.Size([4, 3, 400]) torch.Size([4])
# 257 torch.Size([4, 3, 400]) torch.Size([4])
# 258 torch.Size([4, 3, 400]) torch.Size([4])
# 259 torch.Size([4, 3, 400]) torch.Size([4])
# 260 torch.Size([4, 3, 400]) torch.Size([4])
# 261 torch.Size([4, 3, 400]) torch.Size([4])
# 262 torch.Size([4, 3, 400]) torch.Size([4])
# 263 torch.Size([4, 3, 400]) torch.Size([4])
# 264 torch.Size([4, 3, 400]) torch.Size([4])
# 265 torch.Size([4, 3, 400]) torch.Size([4])
# 266 torch.Size([4, 3, 400]) torch.Size([4])
# 267 torch.Size([4, 3, 400]) torch.Size([4])
# 268 torch.Size([4, 3, 400]) torch.Size([4])
# 269 torch.Size([4, 3, 400]) torch.Size([4])
# 270 torch.Size([4, 3, 400]) torch.Size([4])
# 271 torch.Size([4, 3, 400]) torch.Size([4])
# 272 torch.Size([4, 3, 400]) torch.Size([4])
# 273 torch.Size([4, 3, 400]) torch.Size([4])
# 274 torch.Size([4, 3, 400]) torch.Size([4])
# 275 torch.Size([4, 3, 400]) torch.Size([4])
# 276 torch.Size([4, 3, 400]) torch.Size([4])
# 277 torch.Size([4, 3, 400]) torch.Size([4])
# 278 torch.Size([4, 3, 400]) torch.Size([4])
# 279 torch.Size([4, 3, 400]) torch.Size([4])
# 280 torch.Size([4, 3, 400]) torch.Size([4])
# 281 torch.Size([4, 3, 400]) torch.Size([4])
# 282 torch.Size([4, 3, 400]) torch.Size([4])
# 283 torch.Size([4, 3, 400]) torch.Size([4])
# 284 torch.Size([4, 3, 400]) torch.Size([4])
# 285 torch.Size([4, 3, 400]) torch.Size([4])
# 286 torch.Size([4, 3, 400]) torch.Size([4])
# 287 torch.Size([4, 3, 400]) torch.Size([4])

# %% [markdown]
# # Creating GAN
