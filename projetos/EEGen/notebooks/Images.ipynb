# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Real_acc = [0.7222, 0.3472, 0.8889, 0.4861, 0.3403, 0.3750, 0.6771, 0.7535, 0.7812]
Gau_acc = [0.7639, 0.4375, 0.9028, 0.5556, 0.4271, 0.4514, 0.7674, 0.7674, 0.8229]
DCGAN_acc = [0.9931, 1.0000, 0.9757, 0.8472, 1.0000, 0.5000, 1.0000, 0.4757, 0.6840]
CCNVAE_acc = [0.2361, 0.4097, 0.2500, 0.4583, 1.0000, 0.2083, 0.2083, 0.2500, 0.2083]

# %%
plt.figure(figsize=(10,5))
plt.plot(Real_acc, label = 'Dados Reais', color = 'red')
plt.plot(Gau_acc, label = 'Ruido Gaussiano', color = 'blue')
plt.plot(DCGAN_acc, label = 'DCGAN', color = 'green')
plt.plot(CCNVAE_acc, label = 'CNN-VAE', color = 'yellow')
plt.xlabel('subjects')
plt.ylabel('acc')
plt.title('Accuracy')
plt.legend()
plt.show()

# %%
Gau_tstr = [0.8299, 0.6146, 0.9097, 0.6701, 0.5486, 0.6250, 0.8194, 0.8819, 0.8819]
DCGAN_tstr = [0.3507, 0.2257, 0.2674, 0.2361, 0.2257, 0.2431, 0.2882, 0.2361, 0.3160]
CCNVAE_tstr = [0.3264, 0.3438, 0.2257, 0.2535, 0.2986, 0.3576, 0.2257, 0.5104, 0.3715]

# %%
plt.figure(figsize=(10,5))
plt.plot(Gau_tstr, label = 'Ruido Gaussiano', color = 'blue')
plt.plot(DCGAN_tstr, label = 'DCGAN', color = 'green')
plt.plot(CCNVAE_tstr, label = 'CNN-VAE', color = 'yellow')
plt.xlabel('subjects')
plt.ylabel('tstr')
plt.title('Train on Synthetic, Test on Real')
plt.legend()
plt.show()

# %%
Gau_trts = [0.7369, 0.5729, 0.8854, 0.6181, 0.5625, 0.5938, 0.7604, 0.8438, 0.8264]
DCGAN_trts = [0.2361, 0.2431, 0.2604, 0.2396, 0.0208, 0.2396, 0.2396, 0.2604, 0.2326]
CCNVAE_trts = [0.2708, 0.2569, 0.2500, 0.2083, 0.2500, 0.2083, 0.2083, 0.2917, 0.2083]

# %%
plt.figure(figsize=(10,5))
plt.plot(Gau_trts, label = 'Ruido Gaussiano', color = 'blue')
plt.plot(DCGAN_trts, label = 'DCGAN', color = 'green')
plt.plot(CCNVAE_trts, label = 'CNN-VAE', color = 'yellow')
plt.xlabel('subjects')
plt.ylabel('trts')
plt.title('Train on Real, Test on Synthetic')
plt.legend()
plt.show()

# %%
Gau_dist = [3774.27, 3774.03, 3774.03, 3774.03, 3774.03, 3774.03, 3774.03, 3774.03, 3774.03]
DCGAN_dist = [12026.15, 9460.54, 13282.85, 11297.04, 8179.27, 17687.66, 11453.51, 17252.79, 24479.88]
CCNVAE_dist = [8591.04, 6566.04, 9053.02, 7784.51, 5905.86, 12611.81, 7558.70, 12714.91, 16784.28]

# %%
plt.figure(figsize=(10,5))
plt.plot(Gau_dist, label = 'Ruido Gaussiano', color = 'blue')
plt.plot(DCGAN_dist, label = 'DCGAN', color = 'green')
plt.plot(CCNVAE_dist, label = 'CNN-VAE', color = 'yellow')
plt.xlabel('subjects')
plt.ylabel('dist')
plt.title('Distância Euclidiana')
plt.legend()
plt.show()
